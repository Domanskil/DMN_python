# %%
# Blackjack
# Od 1 do 7 graczy współzawodniczy z rozdającym
# nie tworzyłem klasy shoe. Utworzyłem obiekt shoe klasy deck i ona pełni tę funkcję. Kart już nie brakuje. 
# Można by się połasić o obiekt zbierający wykorzystane karty, który by można shuflować i zastąpić nim shoe. Czy to będzie zjadać dużo pamięci? czy na dłuższą metę coś zmieni?
# Jeśli zmieni, to niewiele, bo to będzie 6 talii dalej. Pamieci chyba nie zje dużo. 

import karty, gry     

class BJ_Card(karty.Card):
    """ Karta do blackjacka. """
    ACE_VALUE = 1

    @property
    def value(self):
        if self.is_face_up:
            v = BJ_Card.RANKS.index(self.rank) + 1
            if v > 10:
                v = 10
        else:
            v = None
        return v

class BJ_Deck(karty.Deck):
    """ Talia kart do blackjacka. """
    def populate(self):
        for suit in BJ_Card.SUITS: 
            for rank in BJ_Card.RANKS: 
                self.cards.append(BJ_Card(rank, suit))

        

class BJ_Hand(karty.Hand):
    """ Ręka w blackjacku. """
    def __init__(self, name):
        super(BJ_Hand, self).__init__()
        self.name = name

    def __str__(self):
        rep = self.name + ":\t" + super(BJ_Hand, self).__str__()  
        if self.total:
            rep += "(" + str(self.total) + ")"        
        return rep

    @property     
    def total(self):
        # jeśli karta w ręce ma wartość None, to i wartość sumy wynosi None
        for card in self.cards:
            if not card.value:
                return None
        
        # zsumuj wartości kart, traktuj każdego asa jako 1
        t = 0
        for card in self.cards:
              t += card.value

        # ustal, czy ręka zawiera asa
        contains_ace = False
        for card in self.cards:
            if card.value == BJ_Card.ACE_VALUE:
                contains_ace = True
                
        # jeśli ręka zawiera asa, a suma jest wystarczająco niska,
        # potraktuj asa jako 11
        if contains_ace and t <= 11:
            # dodaj tylko 10, ponieważ już dodaliśmy 1 za asa
            t += 10   
                
        return t

    def is_busted(self):
        return self.total > 21


class BJ_Player(BJ_Hand):
    """ Gracz w blackjacku. """
    def is_hitting(self):
        response = gry.ask_yes_no("\n" + self.name + ", chcesz dobrać kartę? (T/N): ")
        return response == "t"

    def bust(self):
        print(self.name, "ma furę.")
        self.lose()

    def lose(self):
        print(self.name, "przegrywa.")

    def win(self):
        print(self.name, "wygrywa.")

    def push(self):
        print(self.name, "remisuje.")

        
class BJ_Dealer(BJ_Hand):
    """ Rozdający w blackjacku. """
    def is_hitting(self):
        return self.total < 17

    def bust(self):
        print(self.name, "ma furę.")

    def flip_first_card(self):
        first_card = self.cards[0]
        first_card.flip()


class BJ_Game(object):
    """ Gra w blackjacka. """
    def __init__(self, names):      
        self.players = []
        for name in names:
            player = BJ_Player(name)
            self.players.append(player)

        self.dealer = BJ_Dealer("Rozdający")

        self.deck = BJ_Deck()
        self.shoe = BJ_Deck()
        self.deck.populate()
        self.deck.populate()
        self.deck.populate()
        self.deck.shuffle()

    @property
    def still_playing(self):
        sp = []
        for player in self.players:
            if not player.is_busted():
                sp.append(player)
        return sp

    def __additional_cards(self, player):
        while not player.is_busted() and player.is_hitting():
            self.deck.deal([player])
            print(player)
            if player.is_busted():
                player.bust()
           
    def play(self):
        # rozdaj każdemu początkowe dwie karty
        self.deck.deal(self.players + [self.dealer], per_hand = 2)
        self.dealer.flip_first_card()    # ukryj pierwszą kartę rozdającego
        for player in self.players:
            print(player)
        print(self.dealer)

        # rozdaj graczom dodatkowe karty
        for player in self.players:
            self.__additional_cards(player)

        self.dealer.flip_first_card()    # odsłoń pierwszą kartę rozdającego 

        if not self.still_playing:
            # ponieważ wszyscy gracze dostali furę, pokaż tylko rękę rozdającego
            print(self.dealer)
        else:
            # daj dodatkowe karty rozdającemu
            print(self.dealer)
            self.__additional_cards(self.dealer)

            if self.dealer.is_busted():
                # wygrywa każdy, kto jeszcze pozostaje w grze
                for player in self.still_playing:
                    player.win()                    
            else:
                # porównaj punkty każdego gracza pozostającego w grze z punktami rozdającego
                for player in self.still_playing:
                    if player.total > self.dealer.total:
                        player.win()
                    elif player.total < self.dealer.total:
                        player.lose()
                    else:
                        player.push()

        # usuń karty wszystkich graczy
        for player in self.players:
            player.clear()
        self.dealer.clear()

#tu będzie self.deck. sprawdź ilość kart i populate i szuffle. ale shuffle musi być shoe i deck.append(shoe)

        if len(self.deck.cards) < 112:
            self.shoe.populate()
            self.shoe.populate()
            self.shoe.populate()
            self.shoe.shuffle()
            self.deck.cards += self.shoe.cards
            self.shoe.clear()

def main():
    print("\t\tWitaj w grze 'Blackjack'!\n")
    
    names = []
    number = gry.ask_number("Podaj liczbę graczy (1 - 7): ", low = 1, high = 8)
    for i in range(number):
        name = input("Wprowadź nazwę gracza: ")
        names.append(name)
    print()
        
    game = BJ_Game(names)

    again = None
    while again != "n":
        game.play()
        again = gry.ask_yes_no("\nCzy chcesz zagrać ponownie?: ")


main()
input("\n\nAby zakończyć program, naciśnij klawisz Enter.")
# Out:
# 		Witaj w grze 'Blackjack'!
# Podaj liczbę graczy (1 - 7):  7
# Wprowadź nazwę gracza:  1
# Wprowadź nazwę gracza:  2
# Wprowadź nazwę gracza:  3
# Wprowadź nazwę gracza:  4
# Wprowadź nazwę gracza:  5
# Wprowadź nazwę gracza:  6
# Wprowadź nazwę gracza:  7
# 1:	7d	3c	(10)
# 2:	6d	Ac	(17)
# 3:	Jd	4h	(14)
# 4:	9d	Kc	(19)
# 5:	9h	7h	(16)
# 6:	10h	2d	(12)
# 7:	Js	2h	(12)
# Rozdający:	XX	2c
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	7d	3c	3h	(13)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	7d	3c	3h	9s	(22)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	6d	Ac	10c	(17)
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	6d	Ac	10c	8d	(25)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	Jd	4h	Ks	(24)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	9d	Kc	2s	(21)
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	9d	Kc	2s	Ad	(22)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	9h	7h	8h	(24)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	10h	2d	Qs	(22)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	Js	2h	Jc	(22)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	4s	2c	(6)
# Czy chcesz zagrać ponownie?:  t
# 1:	10s	As	(21)
# 2:	4d	Qd	(14)
# 3:	5d	4c	(9)
# 4:	6s	3s	(9)
# 5:	8c	10d	(18)
# 6:	Qc	3d	(13)
# 7:	6c	6h	(12)
# Rozdający:	XX	Kh
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	10s	As	9c	(20)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	10s	As	9c	Kd	(30)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	4d	Qd	7s	(21)
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	4d	Qd	7s	Ah	(22)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	5d	4c	5h	(14)
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	5d	4c	5h	5c	(19)
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	5d	4c	5h	5c	7c	(26)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	6s	3s	Qh	(19)
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	6s	3s	Qh	Jh	(29)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	8c	10d	8s	(26)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	Qc	3d	5s	(18)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	Qc	3d	5s	10h	(28)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	6c	6h	8c	(20)
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	6c	6h	8c	4h	(24)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	5s	Kh	(15)
# Czy chcesz zagrać ponownie?:  t
# 1:	6s	4h	(10)
# 2:	10c	As	(21)
# 3:	7d	5s	(12)
# 4:	Qs	8h	(18)
# 5:	3h	8c	(11)
# 6:	5c	2c	(7)
# 7:	Ks	10c	(20)
# Rozdający:	XX	5h
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	6s	4h	Qd	(20)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	6s	4h	Qd	Ac	(21)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	6s	4h	Qd	Ac	6s	(27)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	10c	As	7s	(18)
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	10c	As	7s	Qc	(28)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	7d	5s	Js	(22)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  tt
#
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	Qs	8h	10s	(28)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	3h	8c	Jh	(21)
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	3h	8c	Jh	9d	(30)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	5c	2c	2d	(9)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	5c	2c	2d	Ad	(20)
# 6, chcesz dobrać kartę? (T/N):  tt
#
# 6, chcesz dobrać kartę? (T/N):  tt
#
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	5c	2c	2d	Ad	5c	(15)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	5c	2c	2d	Ad	5c	9h	(24)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	Ks	10c	2d	(22)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	2s	5h	(7)
# Czy chcesz zagrać ponownie?:  t
# 1:	10h	9s	(19)
# 2:	4h	10s	(14)
# 3:	4s	7s	(11)
# 4:	8h	Kd	(18)
# 5:	Kh	9d	(19)
# 6:	3s	6d	(9)
# 7:	7h	3d	(10)
# Rozdający:	XX	9c
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	10h	9s	4d	(23)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	4h	10s	Kc	(24)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	4s	7s	8s	(19)
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	4s	7s	8s	8s	(27)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	8h	Kd	2h	(20)
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	8h	Kd	2h	5d	(25)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	Kh	9d	Ad	(20)
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	Kh	9d	Ad	3c	(23)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	3s	6d	2c	(11)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	3s	6d	2c	9s	(20)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	3s	6d	2c	9s	Ad	(21)
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	3s	6d	2c	9s	Ad	7c	(28)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	7h	3d	Qh	(20)
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	7h	3d	Qh	Jd	(30)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	Qh	9c	(19)
# Czy chcesz zagrać ponownie?:  t
# 1:	Qs	Jc	(20)
# 2:	2h	Kh	(12)
# 3:	Jh	3d	(13)
# 4:	5c	Qd	(15)
# 5:	10d	4c	(14)
# 6:	6d	Kc	(16)
# 7:	2h	7c	(9)
# Rozdający:	XX	3c
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	Qs	Jc	3h	(23)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	2h	Kh	Kc	(22)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	Jh	3d	6h	(19)
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	Jh	3d	6h	Qc	(29)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	5c	Qd	Jc	(25)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	10d	4c	10c	(24)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	6d	Kc	6c	(22)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	2h	7c	8s	(17)
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	2h	7c	8s	5s	(22)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	Js	3c	(13)
# Czy chcesz zagrać ponownie?:  t
# 1:	4s	10s	(14)
# 2:	7s	Qh	(17)
# 3:	5h	Kh	(15)
# 4:	8c	2d	(10)
# 5:	5d	4c	(9)
# 6:	5d	Qc	(15)
# 7:	2s	9s	(11)
# Rozdający:	XX	9h
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	4s	10s	3s	(17)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	4s	10s	3s	Ac	(18)
# 1, chcesz dobrać kartę? (T/N):  t
# 1:	4s	10s	3s	Ac	6d	(24)
# 1 ma furę.
# 1 przegrywa.
# 2, chcesz dobrać kartę? (T/N):  t
# 2:	7s	Qh	6c	(23)
# 2 ma furę.
# 2 przegrywa.
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	5h	Kh	3h	(18)
# 3, chcesz dobrać kartę? (T/N):  t
# 3:	5h	Kh	3h	Qs	(28)
# 3 ma furę.
# 3 przegrywa.
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	8c	2d	2c	(12)
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	8c	2d	2c	4s	(16)
# 4, chcesz dobrać kartę? (T/N):  t
# 4:	8c	2d	2c	4s	7h	(23)
# 4 ma furę.
# 4 przegrywa.
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	5d	4c	Qd	(19)
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	5d	4c	Qd	As	(20)
# 5, chcesz dobrać kartę? (T/N):  t
# 5:	5d	4c	Qd	As	6h	(26)
# 5 ma furę.
# 5 przegrywa.
# 6, chcesz dobrać kartę? (T/N):  t
# 6:	5d	Qc	9c	(24)
# 6 ma furę.
# 6 przegrywa.
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	2s	9s	Ah	(12)
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	2s	9s	Ah	3d	(15)
# 7, chcesz dobrać kartę? (T/N):  t
# 7:	2s	9s	Ah	3d	8d	(23)
# 7 ma furę.
# 7 przegrywa.
# Rozdający:	10d	9h	(19)
# Czy chcesz zagrać ponownie?:  t
# 1:	4c	8h	(12)
# 2:	3c	3s	(6)
# 3:	Ks	10d	(20)
# 4:	9d	Ac	(20)
# 5:	6s	Jh	(16)
# 6:	Ks	Ah	(21)
# 7:	6h	Jd	(16)
# Rozdający:	XX	Jd
# 1, chcesz dobrać kartę? (T/N):  n
#
# 2, chcesz dobrać kartę? (T/N):  n
#
# 3, chcesz dobrać kartę? (T/N):  n
#
# 4, chcesz dobrać kartę? (T/N):  n
#
# 5, chcesz dobrać kartę? (T/N):  n
#
# 6, chcesz dobrać kartę? (T/N):  n
#
# 7, chcesz dobrać kartę? (T/N):  n
# Rozdający:	Jc	Jd	(20)
# 1 przegrywa.
# 2 przegrywa.
# 3 remisuje.
# 4 remisuje.
# 5 przegrywa.
# 6 wygrywa.
# 7 przegrywa.
# Czy chcesz zagrać ponownie?:  n
#
#
# Aby zakończyć program, naciśnij klawisz Enter.
# ''

# %%
import karty, gry     

class BJ_Card(karty.Card):
    """ Karta do blackjacka. """
    ACE_VALUE = 1

    @property
    def value(self):
        if self.is_face_up:
            v = BJ_Card.RANKS.index(self.rank) + 1
            if v > 10:
                v = 10
        else:
            v = None
        return v

class BJ_Deck(karty.Deck):
    """ Talia kart do blackjacka. """
    def populate(self):
        for suit in BJ_Card.SUITS: 
            for rank in BJ_Card.RANKS: 
                self.cards.append(BJ_Card(rank, suit))

# class Shoe(BJ_Deck):
#     def fill_deck(self, deck):
#         deck.cards.append(shoe.cards)
#         shoe.clear()
        

class BJ_Hand(karty.Hand):
    """ Ręka w blackjacku. """
    def __init__(self, name):
        super(BJ_Hand, self).__init__()
        self.name = name

    def __str__(self):
        rep = self.name + ":\t" + super(BJ_Hand, self).__str__()  
        if self.total:
            rep += "(" + str(self.total) + ")"        
        return rep

    @property     
    def total(self):
        # jeśli karta w ręce ma wartość None, to i wartość sumy wynosi None
        for card in self.cards:
            if not card.value:
                return None
        
        # zsumuj wartości kart, traktuj każdego asa jako 1
        t = 0
        for card in self.cards:
              t += card.value

        # ustal, czy ręka zawiera asa
        contains_ace = False
        for card in self.cards:
            if card.value == BJ_Card.ACE_VALUE:
                contains_ace = True
                
        # jeśli ręka zawiera asa, a suma jest wystarczająco niska,
        # potraktuj asa jako 11
        if contains_ace and t <= 11:
            # dodaj tylko 10, ponieważ już dodaliśmy 1 za asa
            t += 10   
                
        return t

    def is_busted(self):
        return self.total > 21


class BJ_Player(BJ_Hand):
    """ Gracz w blackjacku. """
    def is_hitting(self):
        response = gry.ask_yes_no("\n" + self.name + ", chcesz dobrać kartę? (T/N): ")
        return response == "t"

    def bust(self):
        print(self.name, "ma furę.")
        self.lose()

    def lose(self):
        print(self.name, "przegrywa.")

    def win(self):
        print(self.name, "wygrywa.")

    def push(self):
        print(self.name, "remisuje.")

        
class BJ_Dealer(BJ_Hand):
    """ Rozdający w blackjacku. """
    def is_hitting(self):
        return self.total < 17

    def bust(self):
        print(self.name, "ma furę.")

    def flip_first_card(self):
        first_card = self.cards[0]
        first_card.flip()

players = []
for name in names:
    player = BJ_Player(name)
    players.append(player)

dealer = BJ_Dealer("Rozdający")
deck = BJ_Deck()
shoe = BJ_Deck()
deck.populate()
#self.deck.populate()
#self.deck.populate()
deck.shuffle()

# %%
print(deck)
# Out:
# 2c	4c	4d	10c	Qd	3h	Ad	7s	5s	2h	As	8s	10d	7d	Qc	Jd	7h	8d	3d	6s	Qs	9d	5h	Ks	Qh	Kc	Ah	Kh	4s	3s	9h	Js	Jc	10h	Ac	8c	4h	Kd	Jh	7c	10s	8h	6d	6h	5c	9c	3c	5d	9s	2s	6c	2d

# %%
if len(deck.cards) < 112:
    shoe.populate()
    print("shoe populate\n", shoe)
#self.shoe.populate()
#self.shoe.populate()
    shoe.shuffle()
    print("shoe shuffle\n", shoe)
#    shoe.fill_deck(deck.cards)
# Out:
# shoe populate
#  Ac	2c	3c	4c	5c	6c	7c	8c	9c	10c	Jc	Qc	Kc	Ad	2d	3d	4d	5d	6d	7d	8d	9d	10d	Jd	Qd	Kd	Ah	2h	3h	4h	5h	6h	7h	8h	9h	10h	Jh	Qh	Kh	As	2s	3s	4s	5s	6s	7s	8s	9s	10s	Js	Qs	Ks
# shoe shuffle
#  3h	7s	8h	6c	5s	Js	3d	5h	6s	4h	9h	9d	Ks	4d	5d	As	4s	4c	10s	Jh	7h	Kh	Qc	3s	5c	Kd	Ac	6d	2c	8d	Ad	10c	Qs	7d	2h	9s	Ah	10d	9c	Qd	8s	Kc	Jc	2s	Jd	7c	10h	3c	6h	2d	Qh	8c

# %%
print(deck)
# Out:
# 2c	4c	4d	10c	Qd	3h	Ad	7s	5s	2h	As	8s	10d	7d	Qc	Jd	7h	8d	3d	6s	Qs	9d	5h	Ks	Qh	Kc	Ah	Kh	4s	3s	9h	Js	Jc	10h	Ac	8c	4h	Kd	Jh	7c	10s	8h	6d	6h	5c	9c	3c	5d	9s	2s	6c	2d

# %%
deck.cards += shoe.cards

print(deck)
# Out:
# 2c	4c	4d	10c	Qd	3h	Ad	7s	5s	2h	As	8s	10d	7d	Qc	Jd	7h	8d	3d	6s	Qs	9d	5h	Ks	Qh	Kc	Ah	Kh	4s	3s	9h	Js	Jc	10h	Ac	8c	4h	Kd	Jh	7c	10s	8h	6d	6h	5c	9c	3c	5d	9s	2s	6c	2d	3h	7s	8h	6c	5s	Js	3d	5h	6s	4h	9h	9d	Ks	4d	5d	As	4s	4c	10s	Jh	7h	Kh	Qc	3s	5c	Kd	Ac	6d	2c	8d	Ad	10c	Qs	7d	2h	9s	Ah	10d	9c	Qd	8s	Kc	Jc	2s	Jd	7c	10h	3c	6h	2d	Qh	8c

# %%
print(shoe.cards)

print(deck.cards)
# Out:
# [<__main__.BJ_Card object at 0x7fb23c2fcd10>, <__main__.BJ_Card object at 0x7fb23c2fd370>, <__main__.BJ_Card object at 0x7fb23c2fcef0>, <__main__.BJ_Card object at 0x7fb23c2fc470>, <__main__.BJ_Card object at 0x7fb23c2fd2b0>, <__main__.BJ_Card object at 0x7fb23c2fd4f0>, <__main__.BJ_Card object at 0x7fb23c2fc830>, <__main__.BJ_Card object at 0x7fb23c2fcdd0>, <__main__.BJ_Card object at 0x7fb23c2fd310>, <__main__.BJ_Card object at 0x7fb23c2fcd70>, <__main__.BJ_Card object at 0x7fb23c2fcf50>, <__main__.BJ_Card object at 0x7fb23c2fca70>, <__main__.BJ_Card object at 0x7fb23c2fd5b0>, <__main__.BJ_Card object at 0x7fb23c2fc890>, <__main__.BJ_Card object at 0x7fb23c2fc8f0>, <__main__.BJ_Card object at 0x7fb23c2fd130>, <__main__.BJ_Card object at 0x7fb23c2fd250>, <__main__.BJ_Card object at 0x7fb23c2fc3b0>, <__main__.BJ_Card object at 0x7fb23c2fd490>, <__main__.BJ_Card object at 0x7fb23c2fd010>, <__main__.BJ_Card object at 0x7fb23c2fce90>, <__main__.BJ_Card object at 0x7fb23c2fd0d0>, <__main__.BJ_Card object at 0x7fb23c2fc6b0>, <__main__.BJ_Card object at 0x7fb23c2fd1f0>, <__main__.BJ_Card object at 0x7fb23c2fc410>, <__main__.BJ_Card object at 0x7fb23c2fcbf0>, <__main__.BJ_Card object at 0x7fb23c2f7350>, <__main__.BJ_Card object at 0x7fb23c2fc950>, <__main__.BJ_Card object at 0x7fb23c2fc2f0>, <__main__.BJ_Card object at 0x7fb23c2fca10>, <__main__.BJ_Card object at 0x7fb23c2fc770>, <__main__.BJ_Card object at 0x7fb23c2fc5f0>, <__main__.BJ_Card object at 0x7fb23c2fd550>, <__main__.BJ_Card object at 0x7fb23c2fc9b0>, <__main__.BJ_Card object at 0x7fb23c2fccb0>, <__main__.BJ_Card object at 0x7fb23c2fd430>, <__main__.BJ_Card object at 0x7fb23c2fcc50>, <__main__.BJ_Card object at 0x7fb23c2fcad0>, <__main__.BJ_Card object at 0x7fb23c2fc590>, <__main__.BJ_Card object at 0x7fb23c2fcb90>, <__main__.BJ_Card object at 0x7fb23c2fd3d0>, <__main__.BJ_Card object at 0x7fb23c2fc710>, <__main__.BJ_Card object at 0x7fb23c2fc650>, <__main__.BJ_Card object at 0x7fb23c2fd190>, <__main__.BJ_Card object at 0x7fb23c2fcb30>, <__main__.BJ_Card object at 0x7fb23c2fc4d0>, <__main__.BJ_Card object at 0x7fb23c2fcfb0>, <__main__.BJ_Card object at 0x7fb23c2fc350>, <__main__.BJ_Card object at 0x7fb23c2fce30>, <__main__.BJ_Card object at 0x7fb23c2fc7d0>, <__main__.BJ_Card object at 0x7fb23c2fd070>, <__main__.BJ_Card object at 0x7fb23c2fc530>]
# [<__main__.BJ_Card object at 0x7fb23c41d810>, <__main__.BJ_Card object at 0x7fb23c42e520>, <__main__.BJ_Card object at 0x7fb23c24fa10>, <__main__.BJ_Card object at 0x7fb23c426e50>, <__main__.BJ_Card object at 0x7fb23c2ee970>, <__main__.BJ_Card object at 0x7fb23c2dbb30>, <__main__.BJ_Card object at 0x7fb23c2d4590>, <__main__.BJ_Card object at 0x7fb23c2f7fb0>, <__main__.BJ_Card object at 0x7fb23c2f7ef0>, <__main__.BJ_Card object at 0x7fb23c2d9310>, <__main__.BJ_Card object at 0x7fb23c2f7e30>, <__main__.BJ_Card object at 0x7fb23c2fc050>, <__main__.BJ_Card object at 0x7fb23dce3450>, <__main__.BJ_Card object at 0x7fb23c2ccc30>, <__main__.BJ_Card object at 0x7fb23c422d50>, <__main__.BJ_Card object at 0x7fb23c2b4950>, <__main__.BJ_Card object at 0x7fb23c2db890>, <__main__.BJ_Card object at 0x7fb23c2cd9f0>, <__main__.BJ_Card object at 0x7fb23c24f950>, <__main__.BJ_Card object at 0x7fb23c2f7f50>, <__main__.BJ_Card object at 0x7fb23c2fc1d0>, <__main__.BJ_Card object at 0x7fb23c2e5a30>, <__main__.BJ_Card object at 0x7fb23c2dbdd0>, <__main__.BJ_Card object at 0x7fb23c2fc230>, <__main__.BJ_Card object at 0x7fb23c2f7290>, <__main__.BJ_Card object at 0x7fb23c2d4ad0>, <__main__.BJ_Card object at 0x7fb23c3711f0>, <__main__.BJ_Card object at 0x7fb23c2f7d10>, <__main__.BJ_Card object at 0x7fb23c2f7e90>, <__main__.BJ_Card object at 0x7fb23c2f7d70>, <__main__.BJ_Card object at 0x7fb23c2f7a70>, <__main__.BJ_Card object at 0x7fb23c2fc170>, <__main__.BJ_Card object at 0x7fb23c422210>, <__main__.BJ_Card object at 0x7fb23c2f7830>, <__main__.BJ_Card object at 0x7fb23dc97b60>, <__main__.BJ_Card object at 0x7fb23c23e470>, <__main__.BJ_Card object at 0x7fb23c2dba10>, <__main__.BJ_Card object at 0x7fb23c2e0910>, <__main__.BJ_Card object at 0x7fb23c2f7bf0>, <__main__.BJ_Card object at 0x7fb23c23df20>, <__main__.BJ_Card object at 0x7fb23c2fc110>, <__main__.BJ_Card object at 0x7fb23c2f5bb0>, <__main__.BJ_Card object at 0x7fb23c430ec0>, <__main__.BJ_Card object at 0x7fb23c2dbf50>, <__main__.BJ_Card object at 0x7fb23c42e9e0>, <__main__.BJ_Card object at 0x7fb23c426d50>, <__main__.BJ_Card object at 0x7fb23c41c550>, <__main__.BJ_Card object at 0x7fb23c432360>, <__main__.BJ_Card object at 0x7fb23c2fc0b0>, <__main__.BJ_Card object at 0x7fb23c2f7b30>, <__main__.BJ_Card object at 0x7fb23c40f530>, <__main__.BJ_Card object at 0x7fb23dcc0940>, <__main__.BJ_Card object at 0x7fb23c2fcd10>, <__main__.BJ_Card object at 0x7fb23c2fd370>, <__main__.BJ_Card object at 0x7fb23c2fcef0>, <__main__.BJ_Card object at 0x7fb23c2fc470>, <__main__.BJ_Card object at 0x7fb23c2fd2b0>, <__main__.BJ_Card object at 0x7fb23c2fd4f0>, <__main__.BJ_Card object at 0x7fb23c2fc830>, <__main__.BJ_Card object at 0x7fb23c2fcdd0>, <__main__.BJ_Card object at 0x7fb23c2fd310>, <__main__.BJ_Card object at 0x7fb23c2fcd70>, <__main__.BJ_Card object at 0x7fb23c2fcf50>, <__main__.BJ_Card object at 0x7fb23c2fca70>, <__main__.BJ_Card object at 0x7fb23c2fd5b0>, <__main__.BJ_Card object at 0x7fb23c2fc890>, <__main__.BJ_Card object at 0x7fb23c2fc8f0>, <__main__.BJ_Card object at 0x7fb23c2fd130>, <__main__.BJ_Card object at 0x7fb23c2fd250>, <__main__.BJ_Card object at 0x7fb23c2fc3b0>, <__main__.BJ_Card object at 0x7fb23c2fd490>, <__main__.BJ_Card object at 0x7fb23c2fd010>, <__main__.BJ_Card object at 0x7fb23c2fce90>, <__main__.BJ_Card object at 0x7fb23c2fd0d0>, <__main__.BJ_Card object at 0x7fb23c2fc6b0>, <__main__.BJ_Card object at 0x7fb23c2fd1f0>, <__main__.BJ_Card object at 0x7fb23c2fc410>, <__main__.BJ_Card object at 0x7fb23c2fcbf0>, <__main__.BJ_Card object at 0x7fb23c2f7350>, <__main__.BJ_Card object at 0x7fb23c2fc950>, <__main__.BJ_Card object at 0x7fb23c2fc2f0>, <__main__.BJ_Card object at 0x7fb23c2fca10>, <__main__.BJ_Card object at 0x7fb23c2fc770>, <__main__.BJ_Card object at 0x7fb23c2fc5f0>, <__main__.BJ_Card object at 0x7fb23c2fd550>, <__main__.BJ_Card object at 0x7fb23c2fc9b0>, <__main__.BJ_Card object at 0x7fb23c2fccb0>, <__main__.BJ_Card object at 0x7fb23c2fd430>, <__main__.BJ_Card object at 0x7fb23c2fc ...

# %%
shoe.clear()
print(shoe)
print(deck)
# Out:
# <pusta>
# 2c	4c	4d	10c	Qd	3h	Ad	7s	5s	2h	As	8s	10d	7d	Qc	Jd	7h	8d	3d	6s	Qs	9d	5h	Ks	Qh	Kc	Ah	Kh	4s	3s	9h	Js	Jc	10h	Ac	8c	4h	Kd	Jh	7c	10s	8h	6d	6h	5c	9c	3c	5d	9s	2s	6c	2d	3h	7s	8h	6c	5s	Js	3d	5h	6s	4h	9h	9d	Ks	4d	5d	As	4s	4c	10s	Jh	7h	Kh	Qc	3s	5c	Kd	Ac	6d	2c	8d	Ad	10c	Qs	7d	2h	9s	Ah	10d	9c	Qd	8s	Kc	Jc	2s	Jd	7c	10h	3c	6h	2d	Qh	8c
