# %%
# Gracze otrzymują jedną kartę, 
# porównanie wartości kart
# koniec gry i zwycięstwo karty wyższej. 


import karty
import gry

class Game_Card(karty.Card):


    @property
    def value(self):
        if self.is_face_up:
            v = Game_Card.RANKS.index(self.rank) + 1
            if v == 1:
                v = 14
        
        return v


class Player(karty.Hand):  # tu jest zjebana klasa. Ale teraz trawię
    
    
    def __init__(self, name):
        super(Player, self).__init__()
        self.name = name
    
    def __str__(self):
        rep = self.name + ":\t" + super(Player, self).__str__()  
        if self.total:
            rep += "(" + str(self.total) + ")"        
        return rep
    
    def lose(self):
        print(self.name, "przegrywa.")

    def win(self):
        print(self.name, "wygrywa.")

    def push(self):
        print(self.name, "remisuje.")

class Game(object):
    
    def __init__(self, names):      
        self.players = []
        for name in names:
            player = Player(name)
            self.players.append(player)

        self.deck = karty.Deck
        self.deck.populate()
        self.deck.shuffle()


    def play(self):
        
        self.deck.deal(self.players, per_hand = 1)
           
        while len(self.players) > 1:
            
            players.sort(player.card.value, reverse = True)
            
            # for player in self.players:
            #     #print(player)
            #     self.players.remove(player)
            #     for player_1 in players:
            #         if player.card.value >
            







def main():
    print("\t\tWitaj w grze 'One Card Game'!\n")
    
    names = []
    number = gry.ask_number("Podaj liczbę graczy (1 - 7): ", low = 1, high = 8)
    for i in range(number):
        name = input("Wprowadź nazwę gracza: ")
        names.append(name)
    print()
        
    game = Game(names)

    again = None
    while again != "n":
        game.play()
        again = gry.ask_yes_no("\nCzy chcesz zagrać ponownie?: ")


main()
input("\n\nAby zakończyć program, naciśnij klawisz Enter.")
# Out:
# 		Witaj w grze 'One Card Game'!
# Podaj liczbę graczy (1 - 7):  2
# Wprowadź nazwę gracza:  a
# Wprowadź nazwę gracza:  s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 85
#      81         game.play()
#      82         again = gry.ask_yes_no("\nCzy chcesz zagrać ponownie?: ")
#      83
#      84
# ---> 85 main()
#      86 input("\n\nAby zakończyć program, naciśnij klawisz Enter.")
#
# Cell In[1], line 77, in main()
#      73         name = input("Wprowadź nazwę gracza: ")
#      74         names.append(name)
#      75     print()
#      76
# ---> 77     game = Game(names)
#      78
#      79     again = None
#      80     while again != "n":
#
# Cell In[1], line 38, in Game.__init__(self, names)
#      35     def __init__(self, names):
#      36         self.players = []
#      37         for name in names:
# ---> 38             player = Player(name)
#      39             self.players.append(player)
#      40
#      41         self.deck = karty.Deck
#
# TypeError: Hand.__init__() takes 1 positional argument but 2 were given
